# %%
import pandas as pd

# %%
world1_path=r'..\23-Final-Project\world_data1.csv'

# %%
world1 = pd.read_csv(world1_path, low_memory=False, encoding="utf-8")
world1
# Out:
#                  Country  Mean Assistance (2011-2016)  Mean CO2 (2011-2016)  \
# 0            Afghanistan                 5.308612e+09           9703.495000
# 1                Albania                 2.976650e+08           4953.505000
# 2                Algeria                 1.533983e+08         139031.861700
# 3                 Angola                 2.573450e+08          35430.556670
# 4    Antigua and Barbuda                 3.886667e+06            532.325000
# ..                   ...                          ...                   ...
# 194              Vietnam                 3.636665e+09         165060.838300
# 195   West Bank and Gaza                 2.300815e+09           2661.020000
# 196          Yemen, Rep.                 1.245327e+09          18875.270000
# 197               Zambia                 9.828650e+08           4122.318333
# 198             Zimbabwe                 7.924700e+08          10780.370000
#
#      Mean Employment (2011-2016)  Mean GDP (2011-2016)
# ...

# %%
world1_df = pd.DataFrame(world1, columns = ['Country', 'Mean Assistance (2011-2016)', 'Mean CO2 (2011-2016)', 'Mean Employment (2011-2016)', 'Mean GDP (2011-2016)']) 
                  
# splitting the dataframe into 2 parts 
# on basis of 'Mean Assistance (2011-2016)' column values 
# using Relational operator 
world2_df = world1_df[world1_df['Mean Assistance (2011-2016)'] == 0 ] 
  
# printing world2_df 
world2_df
# Out:
#                        Country  Mean Assistance (2011-2016)  \
# 7                        Aruba                          0.0
# 8                    Australia                          0.0
# 9                      Austria                          0.0
# 11                Bahamas, The                          0.0
# 12                     Bahrain                          0.0
# 14                    Barbados                          0.0
# 16                     Belgium                          0.0
# 19                     Bermuda                          0.0
# 25           Brunei Darussalam                          0.0
# 26                    Bulgaria                          0.0
# 32                      Canada                          0.0
# 33              Cayman Islands                          0.0
# 44                     Croatia                          0.0
# 45                     Curacao                          0.0
# 46                      Cyprus                          0.0
# ...

# %%
world2_df.to_csv('countries_0.csv', encoding='utf-8')

# %%
world3_df = world1_df[world1_df['Mean Assistance (2011-2016)'] >= 1 ] 
world3_df
# Out:
#                  Country  Mean Assistance (2011-2016)  Mean CO2 (2011-2016)  \
# 0            Afghanistan                 5.308612e+09           9703.495000
# 1                Albania                 2.976650e+08           4953.505000
# 2                Algeria                 1.533983e+08         139031.861700
# 3                 Angola                 2.573450e+08          35430.556670
# 4    Antigua and Barbuda                 3.886667e+06            532.325000
# ..                   ...                          ...                   ...
# 194              Vietnam                 3.636665e+09         165060.838300
# 195   West Bank and Gaza                 2.300815e+09           2661.020000
# 196          Yemen, Rep.                 1.245327e+09          18875.270000
# 197               Zambia                 9.828650e+08           4122.318333
# 198             Zimbabwe                 7.924700e+08          10780.370000
#
#      Mean Employment (2011-2016)  Mean GDP (2011-2016)
# ...

# %%
world3_df.to_csv('countries_assistance.csv', encoding='utf-8')
