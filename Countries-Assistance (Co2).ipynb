# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
countries_A = pd.read_csv("C:\\UPenn\\GDP_Analysis\\GDP_Analysis\\Resources\\countries_assistance.csv")
countries_A.head()
# Out:
#    Unnamed: 0              Country  Mean Assistance (2011-2016)  \
# 0           0          Afghanistan                 5.308612e+09
# 1           1              Albania                 2.976650e+08
# 2           2              Algeria                 1.533983e+08
# 3           3               Angola                 2.573450e+08
# 4           4  Antigua and Barbuda                 3.886667e+06
#
#    Mean CO2 (2011-2016)  Mean Employment (2011-2016)  Mean GDP (2011-2016)
# 0            9703.49500                    16.351667           1961.268333
# 1            4953.50500                    18.136667          11050.331670
# 2          139031.86170                    30.910000          12750.568330
# 3           35430.55667                     7.741667           7404.383333
# 4             532.32500                     0.000000          19435.211670

# %%
countries_as= countries_A.drop(columns=["Country"])
countries_as.head()
# Out:
#    Unnamed: 0  Mean Assistance (2011-2016)  Mean CO2 (2011-2016)  \
# 0           0                 5.308612e+09            9703.49500
# 1           1                 2.976650e+08            4953.50500
# 2           2                 1.533983e+08          139031.86170
# 3           3                 2.573450e+08           35430.55667
# 4           4                 3.886667e+06             532.32500
#
#    Mean Employment (2011-2016)  Mean GDP (2011-2016)
# 0                    16.351667           1961.268333
# 1                    18.136667          11050.331670
# 2                    30.910000          12750.568330
# 3                     7.741667           7404.383333
# 4                     0.000000          19435.211670

# %%
countries_as1=countries_as.rename(columns={"Unnamed: 0": "ID"})
countries_as1
# Out:
#       ID  Mean Assistance (2011-2016)  Mean CO2 (2011-2016)  \
# 0      0                 5.308612e+09           9703.495000
# 1      1                 2.976650e+08           4953.505000
# 2      2                 1.533983e+08         139031.861700
# 3      3                 2.573450e+08          35430.556670
# 4      4                 3.886667e+06            532.325000
# ..   ...                          ...                   ...
# 132  194                 3.636665e+09         165060.838300
# 133  195                 2.300815e+09           2661.020000
# 134  196                 1.245327e+09          18875.270000
# 135  197                 9.828650e+08           4122.318333
# 136  198                 7.924700e+08          10780.370000
#
#      Mean Employment (2011-2016)  Mean GDP (2011-2016)
# 0                      16.351667           1961.268333
# 1                      18.136667          11050.331670
# 2                      30.910000          12750.568330
# 3                       7.741667           7404.383333
# 4                       0.000000          19435.211670
# ..                           ...                   ...
# 132                    22.100000           5557.580000
# 133                    27.946667           5482.028333
# 134                    14.271666           3595.601667
# 135                    10.260000           3449.990000
# 136                     7.871667           2522.828333
#
# [137 rows x 5 columns]

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = countries_as1['Mean Assistance (2011-2016)'].values.reshape(-1, 1)
y = countries_as1['Mean CO2 (2011-2016)'].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (137, 1) (137, 1)
# array([[5.30861174e+09],
#        [2.97665006e+08],
#        [1.53398334e+08],
#        [2.57345001e+08],
#        [3.88666667e+06],
#        [5.70133328e+07],
#        [3.11374995e+08],
#        [1.44913334e+08],
#        [2.29558834e+09],
#        [8.87816680e+07],
#        [3.32100000e+07],
#        [5.62900004e+08],
#        [1.16103332e+08],
#        [6.78728322e+08],
#        [5.24620016e+08],
#        [9.24033343e+07],
#        [9.79488342e+08],
#        [1.05510164e+09],
#        [5.46640004e+08],
#        [2.07008333e+08],
#        [7.53003337e+08],
#        [7.06343333e+08],
#        [3.84016670e+08],
#        [5.02488332e+08],
#        [1.41365000e+08],
#        [1.05365335e+09],
#        [7.21116664e+07],
#        [3.00967167e+09],
#        [1.39065001e+08],
#        [6.05666669e+07],
#        [1.30200333e+09],
#        [1.60660001e+08],
#        [1.77950002e+07],
#        [2.12086665e+08],
#        [2.01133336e+08],
#        [2.70819168e+09],
#        [1.67196669e+08],
#        [9.75999983e+06],
#        [9.92700005e+07],
#        [1.09690000e+08],
#        [3.58865666e+09],
#        [9.76866672e+07],
#        [7.95299981e+07],
#        [1.15543334e+08],
#        [5.54331665e+08],
#        [1.52393168e+09],
#        [1.74349998e+07],
#        [3.51940008e+08],
#        [4.95354996e+08],
#        [1.18116667e+08],
#        [9.74249993e+07],
#        [1.18863999e+09],
#        [5.18431666e+08],
#        [2.70893671e+09],
#        [1.16241666e+08],
#        [1.64953664e+09],
#        [5.37649988e+07],
#        [1.84968498e+09],
#        [1.10155000e+08],
#        [2.62538334e+09],
#        [6.69416663e+07],
#        [1.21678332e+08],
#        [5.17616664e+08],
#        [5.61428335e+08],
#        [4.25158335e+08],
#        [7.87428324e+08],
#        [1.93238335e+08],
#        [7.54681681e+08],
#        [2.34031663e+08],
#        [5.33710002e+08],
#        [1.05398168e+09],
#        [3.29166670e+07],
#        [1.21723335e+09],
#        [6.45716659e+07],
#        [3.30618332e+08],
#        [1.12243333e+08],
#        [6.47106679e+08],
#        [1.11056667e+08],
#        [3.96383326e+08],
#        [3.48903336e+08],
#        [1.05501666e+08],
#        [1.79012834e+09],
#        [1.98479498e+09],
#        [1.48503669e+09],
#        [2.21746668e+08],
#        [2.97249998e+07],
#        [9.27514994e+08],
#        [4.80961675e+08],
#        [8.45441671e+08],
#        [2.27501335e+09],
#        [1.88553334e+08],
#        [3.04453172e+09],
#        [2.17683330e+07],
#        [1.85000117e+06],
#        [6.08178335e+08],
#        [8.77333349e+07],
#        [3.87211660e+08],
#        [2.54810002e+08],
#        [1.08367999e+09],
#        [9.92416674e+07],
#        [5.25500011e+07],
#        [9.72360006e+08],
#        [7.60036677e+08],
#        [1.82450000e+07],
#        [6.44470011e+08],
#        [2.48143334e+08],
#        [1.11623666e+09],
#        [1.23934833e+09],
#        [1.37456167e+09],
#        [4.69470011e+08],
#        [2.34356787e+07],
#        [2.26350002e+07],
#        [1.11833336e+07],
#        [1.21205500e+09],
#        [3.22333334e+07],
#        [3.93993003e+09],
#        [3.69225001e+08],
#        [2.70840332e+09],
#        [6.73766696e+07],
#        [2.50576668e+08],
#        [2.65406670e+08],
#        [7.98616664e+07],
#        [7.87901662e+08],
#        [3.07423336e+09],
#        [3.40083332e+07],
#        [3.31183335e+07],
#        [1.65782501e+09],
#        [1.11953664e+09],
#        [3.41850001e+07],
#        [3.30261668e+08],
#        [1.17045001e+08],
#        [4.34600010e+07],
#        [3.63666504e+09],
#        [2.30081500e+09],
#        [1.24532668e+09],
#        [9.82865000e+08],
#        [7.92470001e+08]])

# %%
# Plot the data


plt.scatter(X, y)

# %%
# Create the model and fit the model to the data

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
# Fit the model to the data. 
# Note: This is the training step where you fit the line to the data.

model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Print the coefficient and the intercept for the model

print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[4.98515194e-05]]
# y-axis intercept:  [24027.95066497]

# %%
#Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1850001.17]]
# Max X Value: [[5.30861174e+09]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max

y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]

plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Foreign Aid vs. Co2")
#invert y axis bc looking at co2 reduction
# Out:
# Text(0.5, 1.0, 'Foreign Aid vs. Co2')

# %%
#to calculate MSE and R2


#from sklearn.metrics import mean_squared_error

# %%
X = countries_as1.iloc[:, :2].values
y = countries_as1.iloc[:, 3].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
countries_as2 = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
countries_as2
# Out:
#     Real Values  Predicted Values
# 0      5.965000         16.199150
# 1     19.926666         15.540524
# 2     16.615000         15.923838
# 3     20.628333         15.729259
# 4     10.718333         16.174515
# 5     17.145000         15.644460
# 6     23.040000         16.968561
# 7     24.926667         15.660719
# 8      6.055000         17.903882
# 9     24.828333         15.688219
# 10    22.371667         16.199444
# 11    18.800000         15.536503
# 12     0.000000         15.504794
# 13    23.616667         16.774455
# 14     7.871667         16.444407
# 15     6.158333         18.184814
# 16     6.845000         15.664667
# 17    30.163333         15.767645
# 18    30.236667         15.718032
# 19     7.600000         15.450555
# 20     2.565000         16.656478
# 21    21.730000         15.708207
# 22     0.000000         15.555738
# 23     0.000000         15.235353
# 24    17.955000         15.611074
# 25    16.500000         16.765753
# 26    30.910000         15.370860
# 27    14.341667         15.558590
